# %% [markdown]
# # Project-Bot Account Detection

# %% [markdown]
# ## Data Understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pandas import Series, DataFrame

# %%
file=pd.read_csv("C:/Users/Riya/Desktop/Project_Bot_Account/kaggle_bot_accounts.csv")

File_DFs=pd.DataFrame(file)

File_DFs
# Out:
#             S.N.                     NAME  GENDER  \
# 0              0        Johnny KerrThomas    Male
# 1              1        Dwayne LarsenLara    Male
# 2              2                      NaN    Male
# 3              3  Russell SimmonsPhillips    Male
# 4              4     Jamie WilsonMartinez  Female
# ...          ...                      ...     ...
# 1048570  1048570     Frank MacdonaldCraig    Male
# 1048571  1048571          Jeremy ReedHill    Male
# 1048572  1048572    Colleen JohnsonFowler  Female
# 1048573  1048573       James WilsonRivers    Male
# 1048574  1048574  Jeffery MitchellJohnson    Male
#
#                             EMAIL_ID IS_GLOGIN  FOLLOWER_COUNT  \
# 0            jacksonalan@example.com     False            53.0
# 1               calvin80@example.com      True            16.0
# 2                 qbrown@example.net      True            44.0
# 3         kimberlywagner@example.com      True            23.0
# ...

# %%
File_DFs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   S.N.                   1048575 non-null  int64
#  1   NAME                   986343 non-null   object
#  2   GENDER                 986874 non-null   object
#  3   EMAIL_ID               986823 non-null   object
#  4   IS_GLOGIN              986800 non-null   object
#  5   FOLLOWER_COUNT         986923 non-null   float64
#  6   FOLLOWING_COUNT        986320 non-null   float64
#  7   DATASET_COUNT          986238 non-null   float64
#  8   CODE_COUNT             986809 non-null   float64
#  9   DISCUSSION_COUNT       986638 non-null   float64
#  10  AVG_NB_READ_TIME_MIN   986414 non-null   float64
#  11  REGISTRATION_IPV4      986145 non-null   object
#  12  REGISTRATION_LOCATION  986435 non-null   object
# ...

# %%
File_DFs.sum()
# Out:
# C:\Users\Riya\AppData\Local\Temp\ipykernel_5056\4081856424.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   File_DFs.sum()
# S.N.                    549754241025
# IS_GLOGIN                     360739
# FOLLOWER_COUNT            26631009.0
# FOLLOWING_COUNT           44426613.0
# DATASET_COUNT              2527300.0
# CODE_COUNT                10252576.0
# DISCUSSION_COUNT          64961009.0
# AVG_NB_READ_TIME_MIN     12573570.14
# TOTAL_VOTES_GAVE_NB       17280784.0
# TOTAL_VOTES_GAVE_DS        6415263.0
# TOTAL_VOTES_GAVE_DC        1479706.0
# ISBOT                         264273
# dtype: object

# %%
File_DFs.isna().sum()
# Out:
# S.N.                         0
# NAME                     62232
# GENDER                   61701
# EMAIL_ID                 61752
# IS_GLOGIN                61775
# FOLLOWER_COUNT           61652
# FOLLOWING_COUNT          62255
# DATASET_COUNT            62337
# CODE_COUNT               61766
# DISCUSSION_COUNT         61937
# AVG_NB_READ_TIME_MIN     62161
# REGISTRATION_IPV4        62430
# REGISTRATION_LOCATION    62140
# TOTAL_VOTES_GAVE_NB      61642
# TOTAL_VOTES_GAVE_DS      61860
# TOTAL_VOTES_GAVE_DC      61954
# ISBOT                    62285
# dtype: int64
